# %%
dataset_dir ='C:/MachineLearningPractice/emovo/EMOVOdata'

#Making new folders
base_dir = 'C:/MachineLearningPractice/emovo/EMOVOdataFinal'
os.mkdir(base_dir)

train_dir = os.path.join(base_dir, 'train')
os.mkdir(train_dir)

train_anger_dir = os.path.join(train_dir, 'anger')
os.mkdir(train_anger_dir)

train_fear_dir = os.path.join(train_dir, 'fear')
os.mkdir(train_fear_dir)

train_happiness_dir = os.path.join(train_dir, 'happiness')
os.mkdir(train_happiness_dir)

train_neutral_dir = os.path.join(train_dir, 'neutral')
os.mkdir(train_neutral_dir)

train_sadness_dir = os.path.join(train_dir, 'sadness')
os.mkdir(train_sadness_dir)

test_dir = os.path.join(base_dir, 'test')
os.mkdir(test_dir)

test_anger_dir = os.path.join(test_dir, 'anger')
os.mkdir(test_anger_dir)

test_fear_dir = os.path.join(test_dir, 'fear')
os.mkdir(test_fear_dir)

test_happiness_dir = os.path.join(test_dir, 'happiness')
os.mkdir(test_happiness_dir)

test_neutral_dir = os.path.join(test_dir, 'neutral')
os.mkdir(test_neutral_dir)

test_sadness_dir = os.path.join(test_dir, 'sadness')
os.mkdir(test_sadness_dir)

#Extract files and directories from EMOVOdataset
emotion_dirs=[x[0] for x in os.walk(dataset_dir)][1:]
#print (emotion_dirs)
#print("-----")
emotion_files=[x[2] for x in os.walk(dataset_dir)][1:]
#print(emotion_files)
#print("-------------------------------")

#Define lists per emotion files
anger_dirs=[]
anger_files=emotion_files[0]
fear_files=emotion_files[1]
happiness_files=emotion_files[2]
neutral_files=emotion_files[3]
sadness_files=emotion_files[4]

#Shuffle files
anger_files=shuffle(anger_files)
fear_files=shuffle(fear_files)
happiness_files=shuffle(happiness_files)
neutral_files=shuffle(neutral_files)
sadness_files=shuffle(sadness_files)  

#Split files(67 for training and 17 remaining for testing)
train_anger_files=anger_files[:67]
#print(len(train_anger_files))
test_anger_files=anger_files[67:]

train_fear_files=fear_files[:67]
test_fear_files=fear_files[67:]

train_happiness_files=happiness_files[:67]
test_happiness_files=happiness_files[67:]

train_neutral_files=neutral_files[:67]
test_neutral_files=neutral_files[67:]

train_sadness_files=sadness_files[:67]
test_sadness_files=sadness_files[67:]

# Copy files to the right directories
for i,file in enumerate(train_anger_files):
    print(file)
    print("-------")
    src = os.path.join(emotion_dirs[0], file)
    dst= os.path.join(train_anger_dir, file)
    shutil.copyfile(src, dst)
    
for i,file in enumerate(test_anger_files):
    print(file)
    print("-------")
    src = os.path.join(emotion_dirs[0], file)
    dst= os.path.join(test_anger_dir, file)
    shutil.copyfile(src, dst)
    
for i,file in enumerate(train_fear_files):
    print(file)
    print("-------")
    src = os.path.join(emotion_dirs[1], file)
    dst= os.path.join(train_fear_dir, file)
    shutil.copyfile(src, dst)
    
for i,file in enumerate(test_fear_files):
    print(file)
    print("-------")
    src = os.path.join(emotion_dirs[1], file)
    dst= os.path.join(test_fear_dir, file)
    shutil.copyfile(src, dst)
    
for i,file in enumerate(train_happiness_files):
    print(file)
    print("-------")
    src = os.path.join(emotion_dirs[2], file)
    dst= os.path.join(train_happiness_dir, file)
    shutil.copyfile(src, dst)
    
for i,file in enumerate(test_happiness_files):
    print(file)
    print("-------")
    src = os.path.join(emotion_dirs[2], file)
    dst= os.path.join(test_happiness_dir, file)
    shutil.copyfile(src, dst)
    
for i,file in enumerate(train_neutral_files):
    print(file)
    print("-------")
    src = os.path.join(emotion_dirs[3], file)
    dst= os.path.join(train_neutral_dir, file)
    shutil.copyfile(src, dst)
    
for i,file in enumerate(test_neutral_files):
    print(file)
    print("-------")
    src = os.path.join(emotion_dirs[3], file)
    dst= os.path.join(test_neutral_dir, file)
    shutil.copyfile(src, dst)
    
for i,file in enumerate(train_sadness_files):
    print(file)
    print("-------")
    src = os.path.join(emotion_dirs[4], file)
    dst= os.path.join(train_sadness_dir, file)
    shutil.copyfile(src, dst)
    
for i,file in enumerate(test_sadness_files):
    print(file)
    print("-------")
    src = os.path.join(emotion_dirs[4], file)
    dst= os.path.join(test_sadness_dir, file)
    shutil.copyfile(src, dst)
